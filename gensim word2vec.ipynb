# %%
import sys
from gensim.models import Word2Vec
import logging,gensim,os

#模型的加载
model = Word2Vec.load('/home/zhli7/zhwiki_embedding_t2s.model')
#比较两个词语的相似度,越高越好
print('"唐山" 和 "中国" 的相似度:'+ str(model.similarity('唐山','中国')))
print('"中国" 和 "祖国" 的相似度:'+ str(model.similarity('祖国','中国')))
print('"中国" 和 "中国" 的相似度:'+ str(model.similarity('中国','中国')))
#使用一些词语来限定,分为正向和负向的
result = model.most_similar(positive=['中国', '城市'], negative=['学生'])
print('同"中国"与"城市"二词接近,但是与"学生"不接近的词有:')
for item in result:
    print('   "'+item[0]+'"  相似度:'+str(item[1]))

result = model.most_similar(positive=['男人','权利'], negative=['女人'])
print('同"男人"和"权利"接近,但是与"女人"不接近的词有:')
for item in result:
    print('   "'+item[0]+'"  相似度:'+str(item[1]))

result = model.most_similar(positive=['女人','法律'], negative=['男人'])
print('同"女人"和"法律"接近,但是与"男人"不接近的词有:')
for item in result:
    print('   "'+item[0]+'"  相似度:'+str(item[1]))
#从一堆词里面找到不匹配的
print("老师 学生 上课 校长 , 有哪个是不匹配的? word2vec结果说是:"+model.doesnt_match("老师 学生 上课 校长".split()))
print("汽车 火车 单车 相机 , 有哪个是不匹配的? word2vec结果说是:"+model.doesnt_match("汽车 火车 单车 相机".split()))
print("大米 白色 蓝色 绿色 红色 , 有哪个是不匹配的? word2vec结果说是:"+model.doesnt_match("大米 白色 蓝色 绿色 红色 ".split()))
#直接查看某个词的向量
print('中国的特征向量是:')
print(model['中国'])
# Out:
# Using TensorFlow backend.
# "唐山" 和 "中国" 的相似度:0.389043553638
# "中国" 和 "祖国" 的相似度:0.498630323992
# "中国" 和 "中国" 的相似度:1.0
# 同"中国"与"城市"二词接近,但是与"学生"不接近的词有:
#    "丝绸之路"  相似度:0.6523704528808594
#    "东北亚"  相似度:0.6465838551521301
#    "长三角"  相似度:0.6447476148605347
#    "经济带"  相似度:0.630073070526123
#    "亚太地区"  相似度:0.6252445578575134
#    "塞姆利亚"  相似度:0.6224442720413208
#    "国家"  相似度:0.6224409937858582
#    "故事类"  相似度:0.6086348295211792
#    "中东"  相似度:0.6085073351860046
#    "商路"  相似度:0.6054806709289551
# 同"男人"和"权利"接近,但是与"女人"不接近的词有:
#    "特权"  相似度:0.8023227453231812
#    "公民权"  相似度:0.7979752421379089
#    "选举权"  相似度:0.7895337343215942
#    "自由权"  相似度:0.7711976766586304
#    "义务"  相似度:0.7692262530326843
#    "自主权"  相似度:0.7668049931526184
#    "隐私权"  相似度:0.7653084993362427
#    "豁免权"  相似度:0.7649816870689392
#    "合法性"  相似度:0.7552136778831482
#    "尊严"  相似度:0.7478142380714417
# 同"女人"和"法律"接近,但是与"男人"不接近的词有:
#    "普通法"  相似度:0.8619130849838257
#    "司法"  相似度:0.8202387690544128
#    "民事"  相似度:0.8030362725257874
#    "成文法"  相似度:0.7957074642181396
#    "人权法"  相似度:0.7950402498245239
#    "立法"  相似度:0.789557695388794
#    "劳动法"  相似度:0.7772917747497559
#    "国际法"  相似度:0.774396538734436
#    "刑事法"  相似度:0.7675758600234985
#    "习惯法"  相似度:0.7651984691619873
# 老师 学生 上课 校长 , 有哪个是不匹配的? word2vec结果说是:校长
# 汽车 火车 单车 相机 , 有哪个是不匹配的? word2vec结果说是:相机
# 大米 白色 蓝色 绿色 红色 , 有哪个是不匹配的? word2vec结果说是:大米
# 中国的特征向量是:
# [ 3.21627522 -3.87661529 -4.78561258 -2.55390501 -1.03865659  3.87361336
#   0.09340569 -0.78227699 -1.28832054 -0.35170171  3.96907163 -2.66962838
#   1.17265475  0.91315341  1.87963367 -0.21392952 -1.87066448  0.58678246
#  -4.37432241 -2.03481078 -5.24687433  0.31201479 -0.67480314  1.98764038
#   2.30609345  1.21669197 -1.50226474 -4.52648926  1.38227904 -4.63686752
#   1.18683755  0.05132471 -0.02340939  6.93497515  1.06635451 -2.73878908
#  -0.52352649  1.96695554 -3.75255179 -2.13159752 -0.39035121  2.5396204
#   0.52928823  1.11831737  0.19802049  0.2728501  -3.22438979 -4.15030193
#  -0.7490412   2.62722182]

# %%
def wordsimilarity(word, model):
    semi = ''
    try:
        semi = model.most_similar(word, topn=10)
    except KeyError:
        print('The word not in vocabulary!')
    for term in semi:
        print('%s,%s' % (term[0],term[1]))

# %%
wordsimilarity("沈阳", model)
# Out:
# 哈尔滨,0.8905324935913086
# 大连,0.8696819543838501
# 长春,0.8541757464408875
# 武汉,0.8190374970436096
# 济南,0.7954901456832886
# 吉林,0.7922065854072571
# 青岛,0.7918338775634766
# 天津,0.7877276539802551
# 重庆,0.787360668182373
# 成都,0.7698260545730591
